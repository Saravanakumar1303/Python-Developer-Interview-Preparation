# %% [markdown]
# # Python Developer Interview Preparation - Day 03 🚀
#
# ## Topics Covered
#
# * List Traversal
# * Array/List Size
# * Sum of List Elements
# * Decrement List Values
# * Append Elements to a List
# * Find Elements Less Than K
# * Mean/Average of an Array
# * Missing Number in an Array
# * Second Largest Element
#
# ## Concepts Learned
#
# * Python Lists and Arrays
# * List Manipulation
# * Iteration and Loops
# * Conditional Statements
# * Basic Algorithms
# * Problem-Solving Techniques
# * Logical Reasoning
#
# ## Platform
#
# * GeeksforGeeks (GFG)
#
# ## Tools Used
#
# * Python
# * VS Code
# * Jupyter Notebook
#
# ## Goal
#
# To strengthen Python fundamentals, improve logical thinking and problem-solving skills, and build a strong foundation for Python Developer technical interviews through consistent practice.

# %% [markdown]
# You are given a list that contains integers. You need to print the elements of the list with a space between them.
#
# Input: arr[] = [54, 43, 2, 1, 5]
# Output: 54 43 2 1 5
# Explanation: Just traverse and print the numbers.

# %%
def listTraversal(arr):
    print(*arr)

arr = list(map(int,input("Enter the number seprated by comma:").split(',')))
listTraversal(arr)
# Out:
# 54 43 2 1 5

# %% [markdown]
# Given an array arr[], find the size of the array.
#
# Input: arr[] = [1, 2, 3]
# Output: 3
# Explanation: The size of the array is 3.

# %%
class Solution:
    def getSize(self,arr):
        return len(arr)
    
arr = list(map(int,input("Enter the elements separated by comma:").split(',')))
sol = Solution()
sol.getSize(arr)
# Out:
# 3

# %% [markdown]
# Given a list arr that contains integers, return the sum of the list.
#
# Input: arr = [54, 43, 2, 1, 5]
# Output: 105
# Explanation: Just sum it 54 + 43 + 2 + 1 + 5 = 105.

# %%
def listSum(arr):
    sum = 0
    for i in arr:
        sum +=i
    print(sum)

arr = list(map(int,input("Enter the elements separated by comma:").split(',')))
listSum(arr)

# Another method
# def listSum(arr):
#     return sum(arr)
# Out:
# 105

# %% [markdown]
# Decrement List Values
#
# You are given a list that contains integers. You need to decrement each element of the list by 1 and return the list.
#
# Input: arr = [54, 43, 2, 1, 5]
# Output: 53 42 1 0 4
# Explanation: Just decrement the numbers by 1

# %%
def decrementList(arr):
    for i in range(len(arr)):
        arr[i]-=1
    print(*arr)

arr = list(map(int,input("Enter the elements separated by comma:").split(',')))
decrementList(arr)
# Out:
# 53 42 1 0 4

# %% [markdown]
# Append To List
#
# You are given three inputs a, b, c. You need to create a list and append a, b, c to the list and then return that list.
#
# Input: a = 1, b = 2, c = 3
# Output: 1 2 3
# Explanation: Just create a list and append 1 2 3 to it. Then return [1,2,3] list.

# %%
def appendList(a,b,c):
    list = []
    list.extend([a,b,c])
    print(list)

a,b,c = map(int,input().split(','))
appendList(a,b,c)
# Out:
# [1, 2, 3]

# %% [markdown]
# Less Than
#
# You are given a number k and a list arr[] that contains integers. You need to return list of numbers that are less than k.
#
# Input: arr[] = [54, 43, 2, 1, 5], k = 6
# Output: 2 1 5
# Explanation: 2 1 5 are less than 6.

# %%
class Solution:
    def lessThan(self,arr,k):
        list =[]
        for i in arr:
            if i<k:
                list.append(i)
        print(*list)

arr =list(map(int,input().split(',')))
k = int(input())
sol = Solution()
sol.lessThan(arr,k)
# Out:
# 2 1 5

# %% [markdown]
# Mean or Average of an Array
#
# Given an array arr[], return the floor value of the mean of its elements.
#
# Input: arr[] = [1, 3, 4, 2, 6, 5, 8, 7]
# Output: 4
# Explanation: Sum of the elements is 1 + 3 + 4 + 2 + 6 + 5 + 8 + 7 = 36, Mean = 36/8 = 4.5, floor(4.5) = 4.

# %%
import math
class Solution:
    def findMean(self, arr):
        sum =0
        for i in arr:
            sum +=i
            mean = math.floor(sum/len(arr))
        print(mean)

arr =list(map(int,input().split(',')))
sol = Solution()
sol.findMean(arr)
# Out:
# 4

# %% [markdown]
# Missing in Array
#
# You are given an array arr[] of size n - 1 that contains distinct integers in the range from 1 to n (inclusive). This array represents a permutation of the integers from 1 to n with one element missing. Your task is to identify and return the missing element.
#
#
# Input: arr[] = [1, 2, 3, 5]
# Output: 4
# Explanation: All the numbers from 1 to 5 are present except 4.

# %%
class Solution:
    def missingNum(self,arr):
        for i in range(1,len(arr)+2):
            if i not in arr:
                return i

arr = list(map(int,input().split(',')))
sol = Solution()
output = sol.missingNum(arr)
print(output)
# Out:
# 4

# %%
# Another Approach

class Solution:
    def missingNum(self, arr):
        n = len(arr)
        expected_sum = (n + 1) * (n + 2) // 2
        actual_sum = sum(arr)
        return expected_sum - actual_sum

# %% [markdown]
# Second Largest
#
# Given an array of positive integers arr[], return the second largest element from the array. If the second largest element doesn't exist then return -1.
#
# Note: The second largest element should not be equal to the largest element.
#
# Input: arr[] = [12, 35, 1, 10, 34, 1]
# Output: 34
# Explanation: The largest element of the array is 35 and the second largest element is 34.
#
# Input: arr[] = [10, 10, 10]
# Output: -1
# Explanation: The largest element of the array is 10 and the second largest element does not exist.

# %%
class Solution:
    def getSecondLargest(self, arr):
        arr = sorted(set(arr))
        if len(arr) < 2:
            return -1
        return arr[-2]
    
arr = list(map(int,input().split(',')))
sol = Solution()
output = sol.getSecondLargest(arr)
print(output)
# Out:
# -1

# %%
# Another Approach

def getSecondLargest(arr):
    if len(arr) < 2:
        return -1
    
    largest = second = -1
    
    for num in arr:
        if num > largest:
            second = largest
            largest = num
        elif num > second and num != largest:
            second = num
    
    return second

arr = list(map(int,input().split(',')))
output = getSecondLargest(arr)
print(output)
# Out:
# 34
