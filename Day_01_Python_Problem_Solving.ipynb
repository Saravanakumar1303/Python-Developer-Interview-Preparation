# %% [markdown]
# # Python Developer Interview Preparation - Day 01
#
# ## Topics Covered
# - Pattern Printing using Nested Loops
# - Factorial
# - Divisor Check
# - Prime Number
# - Next Prime Number
# - Fibonacci Series
# - GCD
# - LCM
# - Rightmost Non-Zero Digit in Array Product
#
# ## Platform
# - GeeksforGeeks (GFG)
#
# ## Goal
# To strengthen Python fundamentals, logical thinking, and problem-solving skills for Python Developer interviews.

# %% [markdown]
# Basic Problems
#
# Given three lines that print the values of a, b, and c. Comment out the line that prints the value of b.
#
# Input: a = 5, b = 6, c = 15
# Output:
# 5
# 15

# %%
a = int(input())
b= int(input())
c= int(input())

print(a)
#print(b)
print(c)
# Out:
# 5
# 15

# %% [markdown]
# You are given two variables, a and b. Your task is to print these variables in the following formats:
#
# With space: Print a and b in a single line, separated by a space, followed by a newline.
# Without newline: Print a and b separated by a space, but do not end the output with a newline.
# With separator: Print a and b separated by a specified separator, followed by a newline.
# Without space: Print a and b in a single line, with no spaces between them, followed by a newline.
#
# Input: a = "Hello", b = "World", separator = '&'
# Output:
# Hello World
# Hello WorldHello&World
# HelloWorld

# %%
a = input()
b = input()
separator = input()[0]

# print with space
print(a,b)

# print without newline
print(a,b,end="")

# print with separator
print(a,b,sep=separator)

# print without space
print(a+b)
# Out:
# Hello World
# Hello WorldHello&World
# HelloWorld

# %% [markdown]
# Given two inputs that are stored in variables a and n, you need to print a, n times in a single line without space between them. Output must have a newline at the end.
# Input: a = "Hello", n = 5
# Output: HelloHelloHelloHelloHello

# %%
a = input()
n = int(input())
print(a*n)
# Out:
# HelloHelloHelloHelloHello

# %% [markdown]
# Given three inputs that are stored in the variables a, b, and c. You need to print a a times and b b times  in a single line separated by c.
# Input: a = 6, b = 4, c = &
# Output: 666666&4444

# %%
a = input()
b = input()
c = input()
int_a = int(a)
int_b = int(b)
print(a*int_a+c+b*int_b)
# Out:
# 666666&4444

# %% [markdown]
# Logical Operators
#
# Input: a = 0, b = 2
# Output: 0 2 True
# Explanation: 0 and 2 gives 0. 0 or 2 gives 2. not 0 give True as 0 is False.

# %%
a = int(input())
b = int(input())
p = a and b         # and operator return first value when it's false otherwise return second value.
q = a or b          # or operator return first value when it's true otherwise return second value.
r = not a           # not operator return true when its false otherwise return false.
print(p,q,r)
# Out:
# 0 2 True

# %% [markdown]
# Conditional and looping statement
# Input: n = 9
# Output: 9 18 27 36 45 54 63 72 81 90

# %%
n = int(input())
for i in range(1,11):
    print(n*i,end=" ")
# Out:
# 9 18 27 36 45 54 63 72 81 90

# %% [markdown]
# Even Positioned Characters
# Input: s = "DoctorPhenomenal"
# Output: DcoPeoea
# Explanation: The even indices characters are printed.

# %%
s = input()
for i in range(0, len(s), 2):
    print(s[i],end="")
# Out:
# DcoPeoea

# %% [markdown]
# Jumping through While
# Given a positive integer x, the task is to print the numbers from 1 to x in the order as 12, 22, 32, 42, 52, ... (in increasing order).
# Input: x = 10
# Output: 1 4 9
# Explanation:From 1 to 10, numbers in powers of 2 are, 12, 22, 32 as 1, 4 and 9.

# %%
x = int(input())
i=1
while(i*i<=x):
    print(i*i, end=" ")
    i+=1
# Out:
# 1 4 9

# %% [markdown]
# Zero Converter
# You are given a number n. The number n can be negative or positive. If n is negative, print numbers from n to 0 by adding 1 to n in the neg function. If positive, print numbers from n-1 to 0 by subtracting 1 from n in the pos function.
#
# Example 1:
# Input:
# n = 4
# Output:
# 3 2 1 0
#
# Example 2:
# Input:
# n = -3
# Output:
# -3 -2 -1 0

# %%
def pos(n):
    while(n>=0):
        n-=1
        print(n,end=" ")
        if n==0:
            break
        
    
def neg(n):
    while(n<=0):
        print(n,end=" ")
        if n==0:
            break
        n+=1

pos_value = pos(4)
neg_value = neg(-3)
# Out:
# 3 2 1 0 -3 -2 -1 0

# %% [markdown]
# FizzBuzz Program

# %%
def fizzbuzz(number):
    if number%3==0 and number%5==0:
        print("FizzBuzz")
    elif number%3==0:
        print("Fizz")
    elif number%5==0:
        print("Buzz")
    else:
        print(number)

fizzbuzz(15)
fizzbuzz(3)
fizzbuzz(5)
fizzbuzz(7)
# Out:
# FizzBuzz
# Fizz
# Buzz
# 7

# %% [markdown]
# Check Leap year or not

# %%
yr = int(input())

if yr % 400 == 0: 
    print("True")
elif yr % 100==0:
    print("False")
elif yr % 4 ==0:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# Calculator
# Given two numbers a and b. You need to perform basic mathematical operations on them. You will be provided an integer named as operator.
#
# If the operator equals to 1 add a and b, then print the result.
# If the operator equals to 2 subtract b from a, then print the result.
# If the operator equals to 3 multiply a and b, then print the result.
# If the operator equals to any other number, print "Invalid Input"(without quotes).
#
# Input: a = 1, b = 2, operator = 3
# Output: 2

# %%
def calc(a,b,op):
    if op==1:
        print(a+b,end="")
    elif op==2:
        print(a-b,end="")
    elif op==3:
        print(a*b,end="")
    else:
        print("Invalid Input")

num_1 = int(input())
num_2 = int(input())
operator = int(input())
calc(num_1,num_2,operator)
# Out:
# 2

# %% [markdown]
# Table Difference
# Given two number n1 and n2, n1 > n2. Find the differences between mathematical tables of n1 and n2 and print in a single line.
# Input: n1 = 9, n2 = 4
# Output: 5 10 15 20 25 30 35 40 45 50
# Explanation:
#   9 18 27 36 45 54 63 72 81 90
# - 4  8 12 16 20 24 28 32 36 40
# -----------------------------------------
# = 5 10 15 20 25 30 35 40 45 50

# %%
def difference(n1, n2):
    for i in range(1, 11):
        print(n1*i - n2*i, end=" ")

num_1 = int(input())
num_2 = int(input())
difference(num_1, num_2)
# Out:
# 5 10 15 20 25 30 35 40 45 50

# %% [markdown]
# Factorial
# Given a positive integer, n. Find the factorial of n.

# %%
def fact(n):
    f=1
    for i in range(1,n+1):
        f = f*i
    return f

num = int(input())
res = fact(num)
print(res)
# Out:
# 120

# %% [markdown]
# All divisors of a Number
# Given an integer n, return all the divisors of n in the ascending order.
# Input: n = 21191
# Output: 1 21191
# Explanation: As 21191 is a prime number, it has only 2 factors(1 and the number itself).

# %%
import math
class Solution:
    def getDivisors(self, n):
        # code here
        divisors = []
        
        for i in range(1, math.isqrt(n)+1):
            if n % i ==0:
                divisors.append(i)
                if i != n//i:
                    divisors.append(n//i)
        
        return sorted(divisors)
        
data = int(input("Enter the number"))
    
sol = Solution()
result = sol.getDivisors(data)
print("Divisors:",result)
# Out:
# Divisors: [1, 21191]

# %% [markdown]
# Given a number n, determine whether it is a prime number or not.
# Note: A prime number is a number greater than 1 that has no positive divisors other than 1 and itself.
#
# Examples :
#
# Input: n = 7
# Output: true
# Explanation: 7 has exactly two divisors: 1 and 7, making it a prime number.
# Input: n = 25
# Output: false
# Explanation: 25 has more than two divisors: 1, 5, and 25, so it is not a prime number.
# Input: n = 1
# Output: false
# Explanation: 1 has only one divisor (1 itself), which is not sufficient for it to be considered prime.

# %%
import math
class Solution:
    def isPrime(self, n):
        if n<=1:
            return False
        if n<=3:
            return True
        if n % 2 ==0 and n % 3 ==0:
            return False
    
        i =5
        while i<= math.isqrt(n):
            if n % i ==0 or n %(i+2) == 0:
                return False
            i+=6
        return True
    
data = int(input())
sol = Solution()
result = sol.isPrime(data)
print(result)
# Out:
# True

# %% [markdown]
# Given an integer n. Write a program to find the first prime number greater than n.
#
# Examples:
#
# Input: n = 15
# Output: 17
# Explanation: 17 is next prime number.

# %%
import math
def nextprime(n):
    candidate = n+1

    while True:
        is_prime = True

        for i in range(2, math.isqrt(candidate)+1):
            if candidate % i == 0:
                is_prime = False
                break
        
        if is_prime and candidate > 1:
            return candidate
            
        candidate+=1

data = int(input())
result = nextprime(data)
print(result)
# Out:
# 37

# %% [markdown]
# Given two positive integers a and b, find GCD of a and b.
#
# Input: a = 20, b = 28
# Output: 4
# Explanation: GCD of 20 and 28 is 4

# %%
class solution:
    def gcd(self, a, b):
        while b!=0:
            r = a % b
            a = b
            b = r
        return a

a = int(input())
b = int(input())

sol = solution()
res = sol.gcd(a,b)
print(res)
# Out:
# 4

# %% [markdown]
# The LCM of two integers is the smallest positive integer that is divisible by both a and b.
#
# Examples:
#
# Input: a = 12, b = 18
# Output: 36
# Explanation: LCM of 12 and 18 is 36

# %%
class Solution:
    def hcf(self, a ,b):
        while b:
            a,b = b,a%b
        return a
    def lcm(self, a, b):
        return (a*b) // self.hcf(a,b)
    
a = int(input())
b = int(input())

sol = Solution()
res = sol.lcm(a,b)
print(res)
# Out:
# 36

# %% [markdown]
# Given an array arr[] of size n containing non-negative integers, return the rightmost non-zero digit in the product of all array elements. If there is no rightmost non-zero digit, return -1.
#
# Input: arr[] = [3, 23, 30, 45]
# Output: 5
# Explanation: Product of these numbers are 93150, rightmost non-zero digit is 5.

# %%
class Solution:
    def rightmostNonZeroDigit (self, arr):
        product = 1

        for num in arr:
            product *=num
        
        if product == 0:
            return -1
        
        s = str(product)
        for ch in reversed(s):
            if ch !='0':
                return int(ch)
        return -1
    
n = int(input("Enter the array size: "))
arr = list(map(int, input("Elements the elements (space separated):").split()))

# Object create பண்ணு
sol = Solution()
result = sol.rightmostNonZeroDigit(arr)
print("Rightmost non-zero digit:", result)
# Out:
# Rightmost non-zero digit: 2
